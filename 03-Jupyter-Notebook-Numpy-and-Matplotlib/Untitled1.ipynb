# %%
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt


x1 = [0,1.66389,2.06323,3.19468,4.25957,4.32612,4.39268,4.52579,4.85857,5.05824,8.78536,27.6206,36.1398,39.5341]
y1 = [0,2622.11,6169.67,9100.26,12185.1,16503.9,27609.3,35475.6,36863.8,48431.9,49820.1,51054,51208.2,51362.5]

x2 = [0,0.998336,1.06489,1.797,2.46256,3.19468,3.92679,4.19301,4.99168,6.38935,11.5807,17.5042,25.1581,30.0166,34.2097]
y2 = [0,616.967,771.208,10951.2,22673.5,33316.2,40719.8,40874,43804.6,45347,48123.4,50282.8,52133.7,52750.6,53059.1]

x3 = [0,4.32612,4.45923,6.45591,6.52246,7.92013,8.25291,9.05158,12.3794,14.3095,14.5092,14.6423,16.772,20.6988,23.8935,24.6922,25.8902,29.0183,30.2163,32.4126]
y3 = [0,771.208,1696.66,2467.87,2930.59,4010.28,6940.87,7712.08,11876.6,19126,19280.2,19434.4,23753.2,36555.3,38251.9,42262.2,43958.9,46735.2,51362.5,53059.1]


plt.plot(x1, y1, color="red", linestyle="-.", label="PB",)
plt.plot(x2, y2, color="green", label="PSNM")
plt.plot(x3, y3, color="blue",linestyle="--", label="SNM")
plt.xlabel("Time [min]")
plt.ylabel("Duplicates [#]")
plt.legend()
plt.title("Cora-dataset") #标题

plt.xlim(0, 40) #坐标轴严格范围（两边没空白）
plt.ylim(0, 60000)

plt.show()

# %%
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt


x1 = [0,6.65434,8.04067,9.14972,11.3678,14.695,21.3494,23.2902,26.8946,33.8262,36.8762,42.1442,52.403,61.8299,79.0203,117.006,138.909]
y1 = [0,22674.4,31976.7,43023.3,61627.9,81976.7,133140,138372,144767,155233,160465,163953,168023,173256,178488,179070,179070]

x2 = [0,4.15896,8.04067,9.98152,12.1996,15.8041,16.9131,17.1904,19.1312,21.0721,24.3993,30.7763,53.2348,103.42]
y2 = [0,11627.9,60465.1,76162.8,98255.8,136628,151744,158140,163372,169767,172093,175000,176744,179651]

x3 = [0,5.82255,8.31793,14.4177,18.0222,27.1719,30.7763,34.9353,42.976,51.8484,58.78,65.7116,74.3068,87.6155]
y3 = [0,1162.79,4069.77,6976.74,24418.6,44767.4,51744.2,59302.3,79069.8,97674.4,111628,127326,148256,179651]


plt.plot(x1, y1, color="red", linestyle="-.", label="PB",)
plt.plot(x2, y2, color="green", label="PSNM")
plt.plot(x3, y3, color="blue",linestyle="--", label="SNM")
plt.xlabel("Time [min]")
plt.ylabel("Duplicates [#]")
plt.legend()
plt.title("DBLP-dataset") #标题

plt.xlim(0, 150) #坐标轴严格范围（两边没空白）
plt.ylim(0, 200000)

plt.show()

# %%
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt


x1 = [0,6.65434,8.04067,9.14972,11.3678,14.695,21.3494,23.2902,26.8946,33.8262,36.8762,42.1442,52.403,61.8299,79.0203,117.006,138.909]
y1 = [0,22674.4,31976.7,43023.3,61627.9,81976.7,133140,138372,144767,155233,160465,163953,168023,173256,178488,179070,179070]

x2 = [0,4.15896,8.04067,9.98152,12.1996,15.8041,16.9131,17.1904,19.1312,21.0721,24.3993,30.7763,53.2348,103.42]
y2 = [0,11627.9,60465.1,76162.8,98255.8,136628,151744,158140,163372,169767,172093,175000,176744,179651]

x3 = [0,5.82255,8.31793,14.4177,18.0222,27.1719,30.7763,34.9353,42.976,51.8484,58.78,65.7116,74.3068,87.6155]
y3 = [0,1162.79,4069.77,6976.74,24418.6,44767.4,51744.2,59302.3,79069.8,97674.4,111628,127326,148256,179651]


plt.plot(x1, y1, color="red", linestyle="-.", label="PB",)
plt.plot(x2, y2, color="green", label="PSNM")
plt.plot(x3, y3, color="blue",linestyle="--", label="SNM")
plt.xlabel("Time [min]")
plt.ylabel("Duplicates [#]")
plt.legend()
plt.title("DBLP-dataset") #标题

plt.xlim(0, 150) #坐标轴严格范围（两边没空白）
plt.ylim(0, 200000)

plt.show()
